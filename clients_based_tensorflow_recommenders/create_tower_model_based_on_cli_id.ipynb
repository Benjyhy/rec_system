# %%
# !pip install tensorflow_recommenders
# !pip install scann
from typing import Dict, Text
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_recommenders as tfrs
from google.colab import drive
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow_recommenders in /usr/local/lib/python3.8/dist-packages (0.7.2)
# Requirement already satisfied: tensorflow>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow_recommenders) (2.11.0)
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow_recommenders) (1.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (22.12.6)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (2.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (3.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (1.51.1)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (2.11.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (1.6.3)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (1.21.6)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (3.1.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (3.19.6)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (0.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (0.28.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (2.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (1.14.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (14.0.6)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (1.15.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (0.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (57.4.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (2.11.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (4.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (21.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tensorflow>=2.9.0->tensorflow_recommenders) (0.38.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.9.0->tensorflow_recommenders) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.9.0->tensorflow_recommenders) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.9.0->tensorflow_recommenders) (2.23.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.9.0->tensorflow_recommenders) (1.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.9.0->tensorflow_recommenders) (2.15.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.9.0->tensorflow_recommenders) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.9.0->tensorflow_recommenders) (1.8.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=2.9.0->tensorflow_recommenders) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=2.9.0->tensorflow_recommenders) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=2.9.0->tensorflow_recommenders) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow>=2.9.0->tensorflow_recommenders) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow>=2.9.0->tensorflow_recommenders) (5.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow>=2.9.0->tensorflow_recommenders) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=2.9.0->tensorflow_recommenders) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow>=2.9.0->tensorflow_recommenders) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow>=2.9.0->tensorflow_recommenders) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow>=2.9.0->tensorflow_recommenders) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow>=2.9.0->tensorflow_recommenders) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow>=2.9.0->tensorflow_recommenders) (3.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->tensorflow>=2.9.0->tensorflow_recommenders) (3.0.9)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scann in /usr/local/lib/python3.8/dist-packages (1.2.9)
# Requirement already satisfied: tensorflow~=2.11.0 in /usr/local/lib/python3.8/dist-packages (from scann) (2.11.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from scann) (1.21.6)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from scann) (1.15.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->scann) (4.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->scann) (1.51.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->scann) (2.1.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->scann) (21.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->scann) (0.2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->scann) (0.4.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->scann) (1.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->scann) (22.12.6)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->scann) (0.28.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->scann) (14.0.6)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->scann) (2.11.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->scann) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->scann) (1.14.1)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->scann) (2.11.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->scann) (2.11.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->scann) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->scann) (3.3.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->scann) (3.19.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->scann) (57.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tensorflow~=2.11.0->scann) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow~=2.11.0->scann) (2.15.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow~=2.11.0->scann) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow~=2.11.0->scann) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow~=2.11.0->scann) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow~=2.11.0->scann) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow~=2.11.0->scann) (2.23.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow~=2.11.0->scann) (3.4.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->scann) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->scann) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->scann) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->scann) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->scann) (5.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->scann) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->scann) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->scann) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->scann) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->scann) (2022.12.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->scann) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->scann) (3.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->tensorflow~=2.11.0->scann) (3.0.9)

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
main_path="/content/drive/MyDrive/Colab Notebooks/Msc2/DAT-901"

# %%
# Create sub datasets : data will be used to train a query model and a candidate model
purchases_df = pd.read_csv(f'{main_path}/all_purchases.csv', index_col=0)
items_df = pd.read_csv(f'{main_path}/all_unique_libelles.csv', index_col=0)

# %%
unique_clients = pd.unique(purchases_df['CLI_ID'])
unique_libelles = pd.unique(items_df['LIBELLE'])

# %%
# Use tensorflow to convert pandas df to tensor slices
purchases = tf.data.Dataset.from_tensor_slices(dict(purchases_df)).prefetch(tf.data.AUTOTUNE)
items = tf.data.Dataset.from_tensor_slices(dict(items_df)).prefetch(tf.data.AUTOTUNE)

# %%
for x in purchases.take(5).as_numpy_iterator():
    print(x)
# Out:
# {'LIBELLE': b'GD JDM4 PAMPLEMOUSSE FL 200ML', 'CLI_ID': 1490281}
# {'LIBELLE': b'GD JDM4 PAMPLEMOUSSE FL 200ML', 'CLI_ID': 1490281}
# {'LIBELLE': b'CR JR PARF BIO.SPE AC.SENT.50ML', 'CLI_ID': 1490281}
# {'LIBELLE': b'EAU MICELLAIRE 3 THES FL200ML', 'CLI_ID': 1490281}
# {'LIBELLE': b'GD JDM4 TIARE FL 200ML', 'CLI_ID': 1490281}

# %%
for x in items.take(5).as_numpy_iterator():
    print(x)
# Out:
# {'LIBELLE': b'GD JDM4 PAMPLEMOUSSE FL 200ML'}
# {'LIBELLE': b'CR JR PARF BIO.SPE AC.SENT.50ML'}
# {'LIBELLE': b'EAU MICELLAIRE 3 THES FL200ML'}
# {'LIBELLE': b'GD JDM4 TIARE FL 200ML'}
# {'LIBELLE': b'EDT  UN MATIN AU JARDIN  100ML  MUGUET'}

# %%
purchases = purchases.map(lambda x: {
    "LIBELLE": x["LIBELLE"],
    "CLI_ID": x["CLI_ID"],
}, num_parallel_calls=tf.data.AUTOTUNE)
items = items.map(lambda x: x["LIBELLE"], num_parallel_calls=tf.data.AUTOTUNE)

# %%
tf.random.set_seed(42)
shuffled = purchases.shuffle(7500000, seed=42, reshuffle_each_iteration=False)

train = shuffled.take(7000000)
test = shuffled.skip(7000000).take(500000)

# %%
clients_vocabulary = tf.keras.layers.experimental.preprocessing.IntegerLookup(mask_token=None, vocabulary=unique_clients)
libelles_vocabulary = tf.keras.layers.experimental.preprocessing.StringLookup(mask_token=None, vocabulary=unique_libelles)

# %%
embedding_dimension = 64

# %%
client_model = tf.keras.Sequential([clients_vocabulary,tf.keras.layers.Embedding(clients_vocabulary.vocabulary_size(),embedding_dimension)])
libelle_model = tf.keras.Sequential([libelles_vocabulary,tf.keras.layers.Embedding(libelles_vocabulary.vocabulary_size(),embedding_dimension)])

# %%
metrics = tfrs.metrics.FactorizedTopK(
    candidates=items.batch(200).map(libelle_model)
)

# %%
task = tfrs.tasks.Retrieval(
    metrics=metrics
)

# %%
class TowerModel(tfrs.Model):

  def __init__(self, client_model, libelle_model):
    super().__init__()
    self.libelle_model: tf.keras.Model = libelle_model
    self.client_model: tf.keras.Model = client_model
    self.task: tf.keras.layers.Layer = task

  def compute_loss(self, features: Dict[Text, tf.Tensor], training=False) -> tf.Tensor:
    client_embeddings = self.client_model(features["CLI_ID"])
    libelle_embeddings = self.libelle_model(features["LIBELLE"])
    return self.task(client_embeddings, libelle_embeddings)

# %%
model = TowerModel(client_model, libelle_model)
model.compile(optimizer=tf.keras.optimizers.Adagrad(
    learning_rate=0.2, 
    initial_accumulator_value=0.1,
    epsilon=1e-07,
))

# %%
cached_train = train.shuffle(7000000).batch(200).cache()
cached_test = test.batch(200).cache()

# %%
early_stop = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=2)

# %%
model.fit(cached_train, epochs=3, callbacks=[early_stop])
# Out:
# Epoch 1/3
# 35000/35000 [==============================] - 3804s 107ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0039 - factorized_top_k/top_5_categorical_accuracy: 0.1408 - factorized_top_k/top_10_categorical_accuracy: 0.2080 - factorized_top_k/top_50_categorical_accuracy: 0.3708 - factorized_top_k/top_100_categorical_accuracy: 0.4515 - loss: 907.9858 - regularization_loss: 0.0000e+00 - total_loss: 907.9858
# Epoch 2/3
# 35000/35000 [==============================] - 3675s 105ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0313 - factorized_top_k/top_5_categorical_accuracy: 0.2813 - factorized_top_k/top_10_categorical_accuracy: 0.4014 - factorized_top_k/top_50_categorical_accuracy: 0.6618 - factorized_top_k/top_100_categorical_accuracy: 0.7632 - loss: 656.2196 - regularization_loss: 0.0000e+00 - total_loss: 656.2196
# Epoch 3/3
# 35000/35000 [==============================] - 3623s 104ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0469 - factorized_top_k/top_5_categorical_accuracy: 0.3123 - factorized_top_k/top_10_categorical_accuracy: 0.4544 - factorized_top_k/top_50_categorical_accuracy: 0.7370 - factorized_top_k/top_100_categorical_accuracy: 0.8324 - loss: 563.3313 - regularization_loss: 0.0000e+00 - total_loss: 563.3313

# %%
model.evaluate(cached_test, return_dict=True)
# Out:
# 1228/1228 [==============================] - 195s 105ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0265 - factorized_top_k/top_5_categorical_accuracy: 0.1369 - factorized_top_k/top_10_categorical_accuracy: 0.2125 - factorized_top_k/top_50_categorical_accuracy: 0.4146 - factorized_top_k/top_100_categorical_accuracy: 0.5111 - loss: 937.5031 - regularization_loss: 0.0000e+00 - total_loss: 937.5031
# {'factorized_top_k/top_1_categorical_accuracy': 0.026531226933002472,
#  'factorized_top_k/top_5_categorical_accuracy': 0.13694903254508972,
#  'factorized_top_k/top_10_categorical_accuracy': 0.212457537651062,
#  'factorized_top_k/top_50_categorical_accuracy': 0.4146471619606018,
#  'factorized_top_k/top_100_categorical_accuracy': 0.5111150741577148,
#  'loss': 463.2264099121094,
#  'regularization_loss': 0,
#  'total_loss': 463.2264099121094}

# %%
scann_index = tfrs.layers.factorized_top_k.ScaNN(model.client_model)
scann_index.index_from_dataset(
  tf.data.Dataset.zip((items.batch(100), items.batch(100).map(model.libelle_model)))
)

# %%
_, rec = scann_index(np.array([int("1490281")]))
print(f"Recommendations for user 1490281: {rec[0, :5]}")
# Out:
# Recommendations for user 1490281: [b'EAU MICELLAIRE 3 THES FL200ML' b'GD FL200ML JDM PAMPLEMOUSSE'
#  b'GD JDM4 CIT VERT FL 200ML' b'GD JDM4 ORANGE FL 200ML'
#  b'CR ANT/ROUG B/SP AC.SENS P50']

# %%
tf.saved_model.save(scann_index,f'{main_path}/retrieval__model__cli_id',options=tf.saved_model.SaveOptions(namespace_whitelist=["Scann"]))
# Out:
# WARNING:absl:Found untraced functions such as query_with_exclusions while saving (showing 1 of 1). These functions will not be directly callable after loading.
